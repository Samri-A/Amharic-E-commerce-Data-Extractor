# %%
import sys
sys.path.append("/scripts")
import vendor

# %%
vendor_ = vendor("/kaggle/input/ec-tg-channel-data/ecommerce_channel_data.csv")

# %% [markdown]
# # MerttEka

# %%
vendor_.Statics_view("MerttEka")
# Out:
# **Statics of channels view**
# count      4944.000000
# mean      25721.669094
# std        9416.019670
# min         530.000000
# 25%       20450.750000
# 50%       26816.000000
# 75%       31054.750000
# max      216453.000000
# Name: views, dtype: float64

# %%
MerttEka_post_frequencey = vendor_.post_frequencey("MerttEka")

# %%
MerttEka_average_views = vendor_.average_views("MerttEka")

# %%
MerttEka_score = vendor_.score(MerttEka_post_frequencey , MerttEka_average_views)
print(f"Leading score {MerttEka_score}")
# Out:
# Leading score 12907.476056359528

# %%
vendor_.max_view_message("MerttEka")
# Out:
# processed_text
# ['መልካም', 'የዕረፍት', 'ቀን', 'ይሁንልዎት']    1
# Name: count, dtype: int64

# %% [markdown]
# # ZemenExpress

# %%
vendor_.Statics_view("ZemenExpress")
# Out:
# **Statics of channels view**
# count     4839.000000
# mean     11956.863815
# std       5983.208188
# min       1119.000000
# 25%       6716.500000
# 50%      11192.000000
# 75%      16708.500000
# max      29997.000000
# Name: views, dtype: float64

# %%
Zemen_post_frequencey = vendor_.post_frequencey("ZemenExpress")

# %%
zemen_average_views = vendor_.average_views("MerttEka")

# %%
zemen_score = vendor_.score(Zemen_post_frequencey , zemen_average_views)
print(f"Leading score {zemen_score}")
# Out:
# Leading score 12906.485490321791

# %%
vendor_.max_view_message("ZemenExpress")
# Out:
# processed_text
# ['የልጆች', 'የምግብ', 'ዕቃ', 'እና', 'ውሃ', 'መጠጫ', 'High', 'Quality', 'ሁለት', '390ml', 'እና', '800ml', 'የምግብ', 'መብያ', 'ሁለት', '300ml', 'የውሃ', 'መጠጫ', '1', 'ማንኪያ', '1', 'ሹኪያ', 'Made', 'in', 'Thailand', 'BPA', 'Free', 'በተለያየ', 'የከለር', 'አማራጭ', 'ዋጋ', '1700', 'ብር', 'ውስን', 'ፍሬ', 'ነው', 'ያለን', 'Limited', 'Stock', 'አድራሻ', 'መገናኛ', 'ደራርቱ', 'ህንፃ', 'ጎን', 'መሰረት', 'ደፋር', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ', 'S05S06', '0902660722', '0928460606', 'በTelegram', 'ለማዘዝ', 'ይጠቀሙ', 'zemencallcenter', 'zemenexpressadmin', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን', 'httpstelegrammezemenexpress']    1
# Name: count, dtype: int64

# %% [markdown]
# # gebeyaadama

# %%
vendor_.Statics_view("gebeyaadama")
# Out:
# **Statics of channels view**
# count     2728.000000
# mean      4214.929985
# std       2112.817495
# min         13.000000
# 25%       3036.250000
# 50%       4085.000000
# 75%       5122.250000
# max      17189.000000
# Name: views, dtype: float64

# %%
gebeyaadama_post_frequencey = vendor_.post_frequencey("gebeyaadama")

# %%
gebeyaadama_average_views = vendor_.average_views("gebeyaadama")

# %%
gebeyaadama_score = vendor_.score(gebeyaadama_post_frequencey ,gebeyaadama_average_views)
print(f"Leading score {gebeyaadama_score}")
# Out:
# Leading score 2133.2008417252255

# %%
vendor_.max_view_message("gebeyaadama")
# Out:
# processed_text
# ['Portable', 'Menstrual', 'heating', 'pad', 'በወር', 'አበባ', 'ወቅት', 'እየታመሙ', 'ተቸግረዋል', 'እንግዲያውስ', 'portable', 'menstrual', 'heating', 'pad', 'ይዘንሎት', 'መጥተየሚሰራ', 'በ', 'ቻርጅ', 'የሚሰራ', '4', 'የሙቀት', 'ደረጃዎች', 'አሉት', '45505560', 'c°', 'በፈለጉት', 'የሙቀት', 'መጠን', 'እያቀያየሩ', 'መጠቀም', 'የሚየስችል', 'ሆድጀርባ', 'ወይም', 'ጎን', 'ላይ', 'ህመም', 'የሚሰማሽ', 'ቦይ', 'ላይ', 'እያቀያየሩ', 'ለመጠቀም', 'የሚመች', 'ስራ', 'ቦታ', 'በ', 'እንቅልፍ', 'ሰአት', 'እና', 'በፈለጉት', 'ሠአት', 'መጠቀም', 'ይቻላል', 'የራሱ', 'ቫይብሬት', 'ስላለው', 'የህመም', 'ስሜትን', 'ያስታግሳል', 'ለፍቅረኛ', 'ለልጅ', 'ቢሉ', 'ለጓደኛ', 'የሚሰጡት', 'ምርጥ', 'እቃ', '0911762201', '0972824252', '0988404491', '0922282582', 'በቴሌግራም', 'ለማዘዝ', 'GebeyaAdama21', 'አድራሻችን', 'አዳማ', 'ፖስታ', 'ቤት', 'ሶሬቲ', 'ሞል', 'ምድር', 'ላይ', 'ሱቁ', '33', 'ይሄንን', 'በመጫን', 'የቤተሰባችን', 'አባል', 'ይሁኑ', 'httpstmegebeyaadama', 'የመረጡትን', 'እቃ', 'ይዘዙ', 'ያሉበት', 'እናደርሳለን', 'በኪስዎ', 'ጥሬ', 'ገንዘብ', 'ካልያዙ', 'በሞባይል', 'ማስተላለፍ', 'ይችላሉ']    1
# Name: count, dtype: int64

# %% [markdown]
# # meneshayeofficial

# %%
vendor_.Statics_view("meneshayeofficial")
# Out:
# **Statics of channels view**
# count      876.000000
# mean      2725.792237
# std       3338.169608
# min        322.000000
# 25%        796.000000
# 50%       1897.000000
# 75%       3288.250000
# max      32641.000000
# Name: views, dtype: float64

# %%
meneshayeofficial_post_frequencey = vendor_.post_frequencey("meneshayeofficial")

# %%
meneshayeofficial_average_views = vendor_.average_views("meneshayeofficial")

# %%
meneshayeofficial_score = vendor_.score(meneshayeofficial_post_frequencey , meneshayeofficial_average_views)
print(f"Leading score {meneshayeofficial_score}")
# Out:
# Leading score 1371.4843540155787

# %%
vendor_.max_view_message("meneshayeofficial")
# Out:
# processed_text
# ['በጉጉት', 'እንደተጠበቀ', 'ብዙ', 'ሆኖ', 'በላቀ', 'ጥራት', 'ደረሰ', 'መነሻዬታብሌትከገላግሌ', 'የአዲሱ', 'ትውልድ', 'አዲስ', 'የእውቀት', 'መንገድ', 'አድራሻ', '1', 'ጉርድ', 'ሾላ', 'ሆሊ', 'ሲቲ', 'ሴንተር', '3ኛ', 'ፎቅ', '2', 'ፒያሳ', 'ካንትሪ', 'ታወር', '2ኛ', 'ፎቅ', '3', 'ጀሞ', 'ደሊና', 'ህንፃ', 'ምድር', 'ላይ', 'ከኦልማርት', 'ጎን', '4', 'ገርጂ', 'መብራት', 'ሃይል', 'ፋውንቴን', 'ህንፃ', '1ኛ', 'ፎቅ', '5', 'አዳማ', '0938093936', '6', 'ሐዋሳ', '0930278917', '7', 'ጅማ', '0985270795', '8', 'ደሴ', '0919191950', 'ይደውሉ', '0989939393', 'ወይም', '0930323334', 'Telegram', 'httptmemeneshayeofficial', 'Tiktok', 'httptiktokcommeneshayeofficial', 'Facebook', 'httpfacebookcommeneshayeofficial', 'Tablet', 'MeneshayeTablet', 'kidstablet', 'uniqetablet', 'latestversionkidstablet', 'iwawa', 'maternalcontrol', 'kidsstore', 'shewit', 'educationaltoys', 'meneshaye', 'meneshayestore']    1
# Name: count, dtype: int64

# %% [markdown]
# # modernshoppingcenter

# %%
vendor_.Statics_view("modernshoppingcenter")
# Out:
# **Statics of channels view**
# count      2075.000000
# mean      20959.351325
# std        7674.167247
# min        2428.000000
# 25%       16608.500000
# 50%       22078.000000
# 75%       25183.000000
# max      192614.000000
# Name: views, dtype: float64

# %%
modernshoppingcenter_post_frequencey = vendor_.post_frequencey("modernshoppingcenter")

# %%
modernshoppingcenter_average_views = vendor_.average_views("modernshoppingcenter")

# %%
modernshoppingcenter_score = vendor_.score(modernshoppingcenter_post_frequencey , modernshoppingcenter_average_views)
print(f"Leading score {modernshoppingcenter_score}")
# Out:
# Leading score 10499.627585727527

# %%
vendor_.max_view_message("modernshoppingcenter")
# Out:
# processed_text
# ['በረፍት', 'ቀንዎ', 'እየተዝናኑ', 'መገብየት', 'ከፈለጉ', 'በ', '2ቱም', 'ቅርንጫፎቻችን', 'ከጠዋቱ', '230', 'እስከ', 'ቀኑ', '1000', 'ክፍት', 'ሆነዉ', 'ይጠብቆዎታል']    1
# Name: count, dtype: int64
